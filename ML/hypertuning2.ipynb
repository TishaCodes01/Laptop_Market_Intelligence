# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('laptop_price_processed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   Ram               1303 non-null   int64
#  5   OpSys             1303 non-null   object
#  6   Weight            1303 non-null   float64
#  7   Price_euros       1303 non-null   float64
#  8   IPS_Panel         1303 non-null   int64
#  9   Retina_Display    1303 non-null   int64
#  10  Touchscreen       1303 non-null   int64
#  11  Resolution_X      1303 non-null   int64
#  12  Resolution_Y      1303 non-null   int64
#  13  Total_Pixels      1303 non-null   int64
#  14  High_Resolution   1303 non-null   int64
#  15  Product_Series    1303 non-null   object
#  16  Cpu_Brand         1303 non-null   object
#  17  Cpu_Series        1303 non-null   object
#  18  Clock_Speed       1303 non-null   float64
#  19  Gpu_Manufacturer  1303 non-null   object
#  20  Gpu_Series        1303 non-null   object
#  21  Memory_Type       1303 non-null   object
#  22  Memory_Size(GB)   1303 non-null   int64
# dtypes: float64(4), int64(10), object(9)
# memory usage: 234.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder
categorical_col = ['TypeName', 'OpSys', 'Cpu_Series', 'Gpu_Series', 'Memory_Type']

le = LabelEncoder()

for col in categorical_col:
  df[col] = le.fit_transform(df[col])

# %%
X = df[['TypeName', 'OpSys', 'Cpu_Series', 'Gpu_Series', 'Memory_Type', 'Price_euros', 'Total_Pixels']]
y = df['Memory_Size(GB)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
from sklearn.ensemble import RandomForestRegressor

rfreg = RandomForestRegressor(n_estimators=312, max_features='log2', max_depth=143, criterion='squared_error', random_state=21, min_samples_split=2, min_samples_leaf=6, max_leaf_nodes=38)
rfreg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=143, max_features='log2', max_leaf_nodes=38,
#                       min_samples_leaf=6, n_estimators=312, random_state=21)

# %%
y_pred = rfreg.predict(X_test)
from sklearn.metrics import r2_score
print(f'Accuracy {r2_score(y_test, y_pred)}')
# Out:
# Accuracy 0.753419457572685

# %%
{'max_depth': 143, 'max_features': 'log2', 'max_leaf_nodes': 38, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 312}
{'max_depth': 123, 'max_features': 'log2', 'max_leaf_nodes': 39, 'min_samples_leaf': 6, 'min_samples_split': 18, 'n_estimators': 220}
{'max_depth': 143, 'max_features': 'log2', 'max_leaf_nodes': 38, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 312}

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distributions = {
    'n_estimators': randint(200, 400), 
    'max_depth': randint(70, 150), 
    'max_leaf_nodes': randint(30,45),         
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(2, 10), 
    'max_features': ['sqrt', 'log2']  
}

random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(criterion='poisson', random_state=21),
    param_distributions=param_distributions,
    n_iter=50, 
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    random_state=21 
)

random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
# Out:
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best Parameters: {'max_depth': 143, 'max_features': 'log2', 'max_leaf_nodes': 38, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 312}
# Best Accuracy: nan

# %%
from xgboost import XGBRegressor
xgbr = XGBRegressor(n_estimators=15, max_depth=4, eta=0.1)
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.1, eval_metric=None,
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=15,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgbr.predict(X_test)
from sklearn.metrics import r2_score
print(f'Accuracy {r2_score(y_test, y_pred)}')
# Out:
# Accuracy 0.7091402555981415

# %%
from sklearn.ensemble import RandomForestClassifier
rfclass = RandomForestClassifier(criterion='gini', n_estimators=234, max_depth=32, min_samples_split=3, min_samples_leaf=5, max_features='sqrt', bootstrap=False)
rfclass.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=32, min_samples_leaf=5,
#                        min_samples_split=3, n_estimators=234)

# %%
y_pred = rfclass.predict(X_test)
from sklearn.metrics import r2_score
print(f'Accuracy {r2_score(y_test, y_pred)}')
# Out:
# Accuracy 0.7019907565254753

# %%
{'criterion': 'gini', 'max_depth': 67, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 137}
{'criterion': 'log_loss', 'n_estimators': 373, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}
{'bootstrap': False, 'criterion': 'gini', 'max_depth': 67, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.001, 'n_estimators': 234}
{'criterion': 'gini', 'n_estimators': 165, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}
{'bootstrap': False, 'criterion': 'gini', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 234}

# %%
from sklearn.model_selection import GridSearchCV

params = {
  'n_estimators' : [134, 234, 389],
  'max_depth' : [32, 47],
  'min_samples_split' : [3, 6, 7],
  'min_samples_leaf' : [5, 4, 7],
  'criterion' : ['entropy', 'gini', 'log_loss'],
  'bootstrap' : [True, False],
  'max_features' : ['sqrt', 'log2']
}

grid = GridSearchCV(estimator=RandomForestClassifier(random_state=21), 
                    param_grid=params, 
                    cv=5, 
                    scoring='accuracy', 
                    n_jobs = -1)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
rf_model = grid.best_estimator_
# Out:
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Best Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 234}

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Define objective function
def objective(trial):
    params = {
        'criterion': trial.suggest_categorical('criterion', ['entropy', 'gini', 'log_loss']),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 30),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'random_state': 21
    }
    
    model = RandomForestClassifier(**params)
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
    return score

# Run Optuna study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Best parameters
print("Best Parameters:", study.best_params)
# Out:
# [I 2025-02-18 17:11:29,976] A new study created in memory with name: no-name-e7bbcd65-f09d-4689-8340-7ae9a10d4b23
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:11:40,356] Trial 0 finished with value: 0.6813397129186602 and parameters: {'criterion': 'entropy', 'n_estimators': 442, 'max_depth': 28, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.6813397129186602.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:11:48,368] Trial 1 finished with value: 0.619976076555024 and parameters: {'criterion': 'gini', 'n_estimators': 240, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.6813397129186602.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:11:57,931] Trial 2 finished with value: 0.6823058520426942 and parameters: {'criterion': 'log_loss', 'n_estimators': 406, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:12:19,313] Trial 3 finished with value: 0.6334468163415531 and parameters: {'criterion': 'entropy', 'n_estimators': 495, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:12:28,196] Trial 4 finished with value: 0.6688811188811189 and parameters: {'criterion': 'gini', 'n_estimators': 391, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:12:35,827] Trial 5 finished with value: 0.6478100846521899 and parameters: {'criterion': 'log_loss', 'n_estimators': 236, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:12:37,103] Trial 6 finished with value: 0.6746273463378726 and parameters: {'criterion': 'log_loss', 'n_estimators': 53, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:12:44,595] Trial 7 finished with value: 0.6170638571954361 and parameters: {'criterion': 'log_loss', 'n_estimators': 435, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6823058520426942.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17

# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:14:50,111] Trial 29 finished with value: 0.6832535885167463 and parameters: {'criterion': 'gini', 'n_estimators': 133, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:14:51,354] Trial 30 finished with value: 0.6707765918292234 and parameters: {'criterion': 'gini', 'n_estimators': 65, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:14:55,426] Trial 31 finished with value: 0.687108943687891 and parameters: {'criterion': 'gini', 'n_estimators': 154, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:14:59,846] Trial 32 finished with value: 0.6832581891792419 and parameters: {'criterion': 'gini', 'n_estimators': 205, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:03,123] Trial 33 finished with value: 0.676532020610968 and parameters: {'criterion': 'gini', 'n_estimators': 210, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:05,043] Trial 34 finished with value: 0.6832673905042326 and parameters: {'criterion': 'gini', 'n_estimators': 95, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:08,127] Trial 35 finished with value: 0.684215126978285 and parameters: {'criterion': 'gini', 'n_estimators': 249, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:10,654] Trial 36 finished with value: 0.6535287081339713 and parameters: {'criterion': 'gini', 'n_estimators': 146, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:13,430] Trial 37 finished with value: 0.6851858667648141 and parameters: {'criterion': 'gini', 'n_estimators': 177, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:15,819] Trial 38 finished with value: 0.6448840633051159 and parameters: {'criterion': 'gini', 'n_estimators': 86, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:19,412] Trial 39 finished with value: 0.6870905410379095 and parameters: {'criterion': 'gini', 'n_estimators': 252, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:21,415] Trial 40 finished with value: 0.61514998159735 and parameters: {'criterion': 'gini', 'n_estimators': 127, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:25,760] Trial 41 finished with value: 0.6909274935590725 and parameters: {'criterion': 'gini', 'n_estimators': 270, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:28,965] Trial 42 finished with value: 0.6899705557600294 and parameters: {'criterion': 'gini', 'n_estimators': 214, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:32,872] Trial 43 finished with value: 0.6871227456753772 and parameters: {'criterion': 'gini', 'n_estimators': 233, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:36,696] Trial 44 finished with value: 0.6851628634523371 and parameters: {'criterion': 'gini', 'n_estimators': 192, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:42,431] Trial 45 finished with value: 0.6842335296282666 and parameters: {'criterion': 'gini', 'n_estimators': 307, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:49,157] Trial 46 finished with value: 0.6467887375782112 and parameters: {'criterion': 'gini', 'n_estimators': 269, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:15:53,820] Trial 47 finished with value: 0.6851720647773278 and parameters: {'criterion': 'gini', 'n_estimators': 217, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:16:03,596] Trial 48 finished with value: 0.6832535885167463 and parameters: {'criterion': 'log_loss', 'n_estimators': 355, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# c:\Users\dabhi\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2025-02-18 17:16:08,748] Trial 49 finished with value: 0.6861198012513803 and parameters: {'criterion': 'gini', 'n_estimators': 268, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 25 with value: 0.6909504968715495.
# Best Parameters: {'criterion': 'gini', 'n_estimators': 165, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}
